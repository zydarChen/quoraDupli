# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import json

# %%
# 数据载入
def dataLoad(path='D:\Program\PycharmProjects\quoraDupli\data\quora_duplicate_questions.tsv'):
    df = pd.read_csv(path, delimiter='\t')
    df = df.dropna(how='any')  # 删除两行缺失数据
    # 转换编码
    df['question1'] = df['question1'].apply(lambda x: unicode(str(x), 'utf-8'))
    df['question2'] = df['question2'].apply(lambda x: unicode(str(x), 'utf-8'))

    print '数据量: %d行' % (df.shape[0])
    rowNum0 = df['is_duplicate'].value_counts()[0]
    rowNum1 = df['is_duplicate'].value_counts()[1]
    print '重复: 不重复 = %d : %d = 1 : %f' \
          % (rowNum1, rowNum0, (rowNum0 * 1.0 / rowNum1))
    uniqueId = set(list(df['qid2'].unique()) + list(df['qid1'].unique()))
    print '问题总数: %d' % (len(uniqueId))
    return df

# %%
# 计算TF-IDF分数
def getTfIdfScore(df):
    from sklearn.feature_extraction.text import TfidfVectorizer

    questions = list(df['question1']) + list(df['question2'])

    tfIdf = TfidfVectorizer(lowercase=False)
    tfIdf.fit_transform(questions)

    word2tfIdf = dict(zip(tfIdf.get_feature_names(), tfIdf.idf_))
    return word2tfIdf

# %%
import os
from tqdm import tqdm
import numpy as np
import en_core_web_md as md

# %%
df = dataLoad()
tfIdfScore = getTfIdfScore(df)
# Out:
# 数据量: 404288行
# 重复: 不重复 = 149263 : 255025 = 1 : 1.708561
# 问题总数: 537931

# %%
nlp = md.load()

# %%
questionList = [list(df['question1']), list(df['question2'])]

# %%
vec = []
for question in tqdm(questionList[0]):
    words = nlp(question)
    mean_vec = np.zeros([len(words), 300])
    for word in words:
        wordVector = word.vector
        try:
            idf = tfIdfScore[str(word)]
        except:
            idf = 0
        mean_vec += wordVector * idf
    mean_vec = mean_vec.mean(axis=0)
    vec.append(mean_vec.tolist())
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 404288/404288 [11:47<00:00, 571.17it/s]

# %%
with open('D:\Program\PycharmProjects\quoraDupli\data\question1.json', 'w') as fp:
    fp.write(json.dumps(vec))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-41686170ed28> in <module>()
#       1 with open('D:\Program\PycharmProjects\quoraDupli\data\question1.json', 'w') as fp:
# ----> 2     fp.write(json.dumps(vec))
#
# C:\ProgramData\Anaconda2\lib\json\__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     242         cls is None and indent is None and separators is None and
#     243         encoding == 'utf-8' and default is None and not sort_keys and not kw):
# --> 244         return _default_encoder.encode(obj)
#     245     if cls is None:
#     246         cls = JSONEncoder
#
# C:\ProgramData\Anaconda2\lib\json\encoder.pyc in encode(self, o)
#     205         # exceptions aren't as detailed.  The list call should be roughly
#     206         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
#     209             chunks = list(chunks)
#
# C:\ProgramData\Anaconda2\lib\json\encoder.pyc in iterencode(self, o, _one_shot)
#     268                 self.key_separator, self.item_separator, self.sort_keys,
#     269                 self.skipkeys, _one_shot)
# --> 270         return _iterencode(o, 0)
#     271
#     272 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# MemoryError:

# %%
len(vec)
# Out:
# 404288

# %%
vec = []
for question in tqdm(questionList[1]):
    words = nlp(question)
    mean_vec = np.zeros([len(words), 300])
    for word in words:
        wordVector = word.vector
        try:
            idf = tfIdfScore[str(word)]
        except:
            idf = 0
        mean_vec += wordVector * idf
    mean_vec = mean_vec.mean(axis=0)
    vec.append(mean_vec)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 404288/404288 [12:51<00:00, 523.98it/s]

# %%
with open('D:\Program\PycharmProjects\quoraDupli\data\question2.json', 'w') as fp:
    fp.write(json.dumps(vec))

# %%
pd.to_pickle(df, 'data/2_word2vec_tfidf.pkl')

# %%
df['q1Vector'] = vec

# %%
pd.to_pickle(df, 'D:\Program\PycharmProjects\quoraDupli\data\question1&2.pickle')

# %%
df['q2Vector'] = vec

# %%
df['q1Vector'][1717]
# Out:
# array([ -10.89369355,   11.25902551,   -5.1187965 ,   -6.06989233,
#          11.99266816,    1.70115947,   -5.61840542,   -3.79112197,
#          -2.71978045,  103.98578262,  -24.09299075,    2.34198799,
#         -10.05585681,   -3.63996656,   -0.6522512 ,   -0.1667682 ,
#          -7.7384637 ,   76.51058149,   -6.41214633,   -4.2586635 ,
#           9.4239338 ,   -2.67132625,   -1.15786346,   -4.58551546,
#          -4.23862864,   -5.27130169,   -4.16966924,    2.80506968,
#           7.22021147,    0.36746059,   -4.10047547,   -2.87639775,
#          -1.1988828 ,   -0.52249566,   -1.57655483,    3.14391417,
#           2.32159036,   -1.53440873,   -7.30013071,   -4.69445034,
#           0.47051984,    7.01570294,    1.72144576,   -9.5606603 ,
#          -0.66424323,    6.90612473,   -6.76487689,   -9.0081695 ,
#          -1.27538522,    6.22450536,   -7.66572031,    0.88944499,
#           2.6314193 ,  -12.96832015,   10.19972441,   -3.85901373,
#           5.33758172,    4.93926939,   -1.321724  ,   -4.46512651,
#          -9.56905556,   -0.15959676,    2.1460884 ,    6.69256147,
#          17.01919327,   -0.28798508,   -3.61335295,    9.69052678,
#           3.56667244,    1.56263015,   -2.11694823,    8.10166708,
#           8.07890037,   -2.20722235,    7.89049981,    6.23955467,
#           4.08576635,   -8.41872963,    2.28840822,    8.97776327,
#           1.51510882,    5.61437633,   -0.63730276,    5.35587148,
#          -2.44386481,  -10.71244198,    6.64469567,   10.79517873,
#          15.38014393,   -7.31295172,   -8.92476977,    6.30840695,
#          -1.55314346,    0.19746775,   10.82431054,   -0.87787577,
#           2.66904671,    5.75227294,   -3.05031833,   -2.77081259,
#          -4.16141604,   -1.93156002,   -3.49948022,   -2.88529552,
#          -1.33143394,  -36.27944034,    6.18238413,    5.26831295,
#          -0.94346647,   -0.5152327 ,    2.07956963,  -16.0448663 ,
#         -2.76466787e+00,   1.74484746e+00,   2.96317559e+00,
#          3.44979325e+00,  -2.20671530e+00,   4.83568920e+00,
#          6.13227838e+00,  -5.23648828e-01,  -3.63092437e+00,
#         -1.71670377e+00,   6.56539643e+00,   1.94768459e+00,
#         -3.37368459e+00,   4.05550347e+00,  -5.13143837e-03,
#          2.15580553e-01,   3.30801687e+00,   2.33984357e+00,
#         -2.90296890e+00,   6.57573255e+00,   1.65422333e-01,
#          2.12222040e-01,   2.32144260e+00,  -1.90758100e+00,
#         -3.49316891e+00,   1.85044092e+00,   5.53058766e-01,
#          4.48820117e+00,   4.15841305e+00,   1.00984126e+00,
#          3.71657699e+00,  -1.15817647e+00,  -1.22397516e+01,
#          9.14675231e+00,   3.62566151e+00,  -5.15282340e+00,
#          2.68242019e+00,   1.41030040e+00,   3.57254010e+00,
#         -1.70696397e+00,   8.05851758e+00,   1.14372166e+01])

# %%
print df['question1'][1717]
print df['question2'][1717]
# Out:
# How can I get a green card to live and work in the USA?
# How can I get a green card?

# %%
vec = []
words = nlp(df['question1'][1717])
mean_vec = np.zeros([len(words), 300])
for word in words:
    wordVector = word.vector
    try:
        idf = tfIdfScore[str(word)]
    except:
        idf = 0
    mean_vec += wordVector * idf
mean_vec = mean_vec.mean(axis=0)
vec.append(mean_vec.tolist())

# %%
vec
# Out:
# [[-10.89369355441886,
#   11.259025506675243,
#   -5.118796497583389,
#   -6.069892330095172,
#   11.99266815930605,
#   1.7011594660580158,
#   -5.618405416607857,
#   -3.7911219745874405,
#   -2.7197804525494576,
#   103.98578262329102,
#   -24.09299075230956,
#   2.3419879898428917,
#   -10.055856809020042,
#   -3.639966562157497,
#   -0.652251198887825,
#   -0.16676820488646626,
#   -7.7384636998176575,
#   76.51058149337769,
#   -6.412146329879761,
#   -4.25866350159049,
#   9.42393379798159,
#   -2.671326246112585,
#   -1.1578634604811668,
#   -4.585515461862087,
#   -4.238628637045622,
#   -5.271301686763763,
#   -4.169669241644442,
#   2.805069677531719,
#   7.220211474224925,
#   0.3674605917185545,
#   -4.1004754703026265,
#   -2.876397754997015,
#   -1.1988828033208847,
#   -0.5224956646561623,
#   -1.5765548311173916,
#   3.1439141668379307,
#   2.3215903639793396,
#   -1.5344087332487106,
#   -7.300130708143115,
#   -4.694450341165066,
#   0.4705198425799608,
#   7.015702936798334,
#   1.7214457616209984,
#   -9.560660302639008,
#   -0.6642432287335396,
#   6.906124731525779,
#   -6.764876887202263,
#   -9.00816949736327,
#   -1.2753852233290672,
#   6.224505364894867,
#   -7.66572031378746,
#   0.8894449919462204,
#   2.63141930103302,
#   -12.968320149928331,
#   10.199724413454533,
#   -3.859013732522726,
#   5.337581715080887,
#   4.939269386231899,
#   -1.321723997592926,
#   -4.4651265144348145,
#   -9.569055559113622,
#   -0.1595967561006546,
#   2.1460883989930153,
#   6.692561469972134,
#   17.019193273037672,
#   -0.2879850808531046,
#   -3.613352954387665,
#   9.690526783466339,
#   -4.758877195417881,
#   0.37953334115445614,
#   12.13292670249939,
#   -7.388624183833599,
#   4.5207510674372315,
#   3.8732015565037727,
#   3.581119120121002,
#   8.870215088129044,
#   -14.432250462472439,
#   2.0159271135926247,
#   1.2417479641735554,
#   9.655314765870571,
#   2.403791330754757,
#   10.51222013682127,
#   1.7558196242898703,
#   2.275649070739746,
#   3.810528200119734,
#   0.8260921016335487,
#   4.298249758780003,
#   -4.550082623958588,
#   -4.103283919394016,
#   -7.984620846807957,
#   3.0684411972761154,
#   -3.7030304111540318,
#   -1.4527452234178782,
#   -10.25289635360241,
#   3.823606425896287,
#   -6.06096737831831,
#   -7.409846186637878,
#   -5.9379248432815075,
#   -1.8100094497203827,
#   -7.19562114495784,
#   2.4430937375873327,
#   5.472820565104485,
#   10.210004821419716,
#   -1.1299993693828583,
#   6.509507122915238,
#   1.173242248594761,
#   6.0893445909023285,
#   13.155288016423583,
#   11.037151485681534,
#   -8.484966844320297,
#   0.6945422701537609,
#   1.6587606333196163,
#   -15.086544409394264,
#   4.286203868687153,
#   13.119945103302598,
#   10.728015819564462,
#   3.881254691630602,
#   -0.9906253293156624,
#   2.820174053311348,
#   8.736535042524338,
#   -14.92976039648056,
#   -5.605141311883926,
#   -9.061293914914131,
#   -15.533720597624779,
#   1.2792755290865898,
#   5.677813472226262,
#   -4.118330294266343,
#   -7.752033829689026,
#   -10.908075660467148,
#   7.687309451401234,
#   9.561741903424263,
#   -0.28565979562699795,
#   0.6335436571389437,
#   -4.7981490679085255,
#   1.733153786510229,
#   9.019413843750954,
#   9.173625603318214,
#   -3.5476825423538685,
#   7.070730313658714,
#   3.6618672311306,
#   -7.118695884943008,
#   -3.31521750241518,
#   -3.0218803230673075,
#   10.232344150543213,
#   7.273614674806595,
#   -8.333655450493097,
#   2.74594384431839,
#   -4.727467270568013,
#   6.215942785143852,
#   6.289151582866907,
#   0.6488066017627716,
#   -1.4373119538649917,
#   10.575058303773403,
#   0.8706395463086665,
#   4.968784272670746,
#   5.58609302341938,
#   -3.1327957585453987,
#   -8.670370876789093,
#   2.70489202439785,
#   -2.7887922525405884,
#   3.1200201623141766,
#   9.700071685016155,
#   -0.9943279325962067,
#   8.687107838690281,
#   -2.846820933293202,
#   -20.233027175068855,
#   6.746777854859829,
#   3.5973552633076906,
#   -4.547913079150021,
#   4.200302957557142,
#   -0.7456958293914795,
#   5.6402421817183495,
#   -3.5354502201080322,
#   2.030009835958481,
#   18.69536191225052]]

# %%
list(df['q2Vector'][1717]) == vec2[0]
# Out:
# True

# %%
vec2 = []
words = nlp(df['question2'][1717])
mean_vec = np.zeros([len(words), 300])
for word in words:
    wordVector = word.vector
    try:
        idf = tfIdfScore[str(word)]
    except:
        idf = 0
    mean_vec += wordVector * idf
mean_vec = mean_vec.mean(axis=0)
vec2.append(mean_vec.tolist())

# %%
df['q2Vector'][1717] == vec2
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True]], dtype=bool)
